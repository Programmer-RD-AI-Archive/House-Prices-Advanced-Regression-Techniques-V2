# %%
# Load the data
# Clean the data
# Feature Enginnering
# Preproccessing
# Modelling
# RandomSearching
# GridSearchings
# Final Project Repat

# %%
import random
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import (
    StandardScaler,
    RobustScaler,
    MinMaxScaler,
    MaxAbsScaler,
    OneHotEncoder,
    LabelEncoder,
    Normalizer,
)
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,VotingRegressor,BaggingRegressor,RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score,precision_score,f1_score,recall_score
import pickle

# %%
import wandb
PROJECT_NAME = 'House-Prices-Advanced-Regression-Techniques-V2'
def valid(model,X,y,val=False):
    y_test = y
    y_preds = model.predict(X)
    if val is True:
        results = {
            'Val Accuracy':model.score(X,y),
            'Val MAE':mean_absolute_error(y_test,y_preds),
            'Val MSE':mean_squared_error(y_test,y_preds),
        }
    else:
        results = {
            'Accuracy':model.score(X,y),
            'MAE':mean_absolute_error(y_test,y_preds),
            'MSE':mean_squared_error(y_test,y_preds),
        }
    return results
def fit(model,X_train,X_test,y_train,y_test,name):
    wandb.init(project=PROJECT_NAME,name=name)
    model = model
    model.fit(X_train,y_train)
    print('Logging')
    wandb.log(valid(model,X_train,y_train))
    wandb.log(valid(model,X_test,y_test,True))
    print('Saving')
    pickle.dump(model,open(f'./models/model-{name}.pkl','wb'))
    print('Making Submissions')
    make_submission(model,name)
    return model
def make_submission(model,name):
    data = pd.read_csv('./test.csv')
    for col_name,col_missing_num in zip(data.columns,data.isna().sum()):
        try:
            data[col_name].fillna(data[col_name].median(),inplace=True)
        except:
            data[col_name].fillna(random.choice(data[col_name].dropna().tolist()),inplace=True)
    ids = data['Id']
    for col_name,col_dtype in zip(data.columns,data.dtypes):
        if col_dtype == 'object':
            labels = object_to_int(data,col_name)
            new_col_data = []
            for i in data[col_name]:
                new_col_data.append(labels[i])
            data[col_name] = new_col_data
    preds = model.predict(data)
    df = pd.DataFrame({'Id':ids,'SalePrice':preds})
    df.to_csv(f'./submissions/submisssion-{name}.csv',index=False)
    return df

# %%
data = pd.read_csv('./train.csv')

# %%
for col_name,col_missing_num in zip(data.columns,data.isna().sum()):
    try:
        data[col_name].fillna(data[col_name].median(),inplace=True)
    except:
        data[col_name].fillna(random.choice(data[col_name].dropna().tolist()),inplace=True)

# %%
def object_to_int(data,col):
    labels = {}
    idx = -1
    for label in data[col]:
        if label not in list(labels.keys()):
            idx += 1
            labels[label] = idx
    return labels

# %%
for col_name,col_dtype in zip(data.columns,data.dtypes):
    if col_dtype == 'object':
        labels = object_to_int(data,col_name)
        new_col_data = []
        for i in data[col_name]:
            new_col_data.append(labels[i])
        data[col_name] = new_col_data

# %%
corr_matrix = data.corr()

# %%
new_dict = {}
for key,val in zip(corr_matrix.to_dict().keys(),corr_matrix.to_dict().values()):
    for key_inside,val_inside in zip(val.keys(),val.values()):
        if val_inside > -0.0:
            try:
                new_dict[key][key_inside] = val_inside
            except:
                new_dict[key] = {}
                new_dict[key][key_inside] = val_inside
list_of_cols_to_keep = []
for key,val in zip(new_dict.keys(),new_dict.values()):
    for key_inside,val_inside in zip(val.keys(),val.values()):
        if key_inside in list_of_cols_to_keep:
            pass
        else:
            list_of_cols_to_keep.append(key_inside)

# %%
len(list_of_cols_to_keep)
# Out:
# 81

# %%
data = data[list_of_cols_to_keep]

# %%
len(data.columns)
# Out:
# 81

# %%
corr_matrix = data.corr()
fig,ax = plt.subplots(figsize=(50,25))
ax = sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt='.2f',cmap='YlGnBu')

# %%
X = data.drop('SalePrice',axis=1)
y = data['SalePrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.125)

# %%
fit(RandomForestRegressor(),X_train,X_test,y_train,y_test,name='baseline')
# Out:
# Finishing last run (ID:hoyuyr16) before initializing another...
# <br/>Waiting for W&B process to finish, PID 494790<br/>Program ended successfully.
# VBox(children=(Label(value=' 1.92MB of 1.92MB uploaded (1.91MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/indika/Programming/Projects/Python/Artifical-Intelligence/Sklearn/Regression/House-Prices-Advanced-Regression-Techniques-V2/wandb/run-20210809_213523-hoyuyr16/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/indika/Programming/Projects/Python/Artifical-Intelligence/Sklearn/Regression/House-Prices-Advanced-Regression-Techniques-V2/wandb/run-20210809_213523-hoyuyr16/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Accuracy</td><td>0.96782</td></tr><tr><td>MAE</td><td>10605.06091</td></tr><tr><td>MSE</td><td>203093400.21575</td></tr><tr><td>_runtime</td><td>7</td></tr><tr><td>_timestamp</td><td>1628525130</td></tr><tr><td>_step</td><td>1</td></tr><tr><td>Val Accuracy</td><td>0.88347</td></tr><tr><td>Val MAE</td><td>16491.12546</td></tr><tr><td>Val MSE</td><td>730759301.60909</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Accuracy</td><td>▁</td></tr><tr><td>MAE</td><td>▁</td></tr><tr><td>MSE</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁</td></tr><tr><td>_timestamp</td><td>▁▁</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>Val Accuracy</td><td>▁</td></tr><tr><td>Val MAE</td><td>▁</td></tr><tr><td>Val MSE</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline</strong>: <a href="https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1/runs/hoyuyr16" target="_blank">https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1/runs/hoyuyr16</a><br/>
# ...Successfully finished last run (ID:hoyuyr16). Initializing new run:<br/><br/>
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1" target="_blank">https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1</a><br/>
#                 Run page: <a href="https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1/runs/1mbbfl9d" target="_blank">https://wandb.ai/ranuga-d/House-Prices-Advanced-Regression-Techniques-V1/runs/1mbbfl9d</a><br/>
#                 Run data is saved locally in <code>/home/indika/Programming/Projects/Python/Artifical-Intelligence/Sklearn/Regression/House-Prices-Advanced-Regression-Techniques-V2/wandb/run-20210809_213616-1mbbfl9d</code><br/><br/>
# Logging
# Saving
# Making Submissions
# RandomForestRegressor()
